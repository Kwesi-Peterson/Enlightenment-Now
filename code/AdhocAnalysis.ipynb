# %%
# Based on the PowerBI analysis, there are 4 additional questions I'd like to explore.
# (1) Data appears to be a bit incomplete! What's the distribution of incompleteness per country, year and indicator?
# (2) For the UK table, can we calculate the rolling average over N years for each indicator?
# (3) For the 2012 table, can we calculate which countries have the min/max value for each indicator?
# (4) For the Education table, can we calculate which countries have the worst gender split?
#
# Firstly, get the tables from the default database:
from pyspark.sql.functions import col
dimTableCountry = spark.table("dimensiontablecountrycode")
dimTableDate = spark.table("dimensiontabledate")
dimTableIndicator = spark.table("dimensiontableindicatorcode")
factTable = spark.table("facttable")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Explore question (1) - what's the distribution of incompleteness per country, year and indicator?
# The quickest possible way is to use the dbuitls.data.summarize command.
dbutils.data.summarize(factTable)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2203931831861034&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># Explore question (1) - what&#39;s the distribution of incompleteness per country, year and indicator?</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> <span class="ansi-red-fg"># The quickest possible way is to use the dbuitls.data.summarize command.</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>dbutils<span class="ansi-blue-fg">.</span>data<span class="ansi-blue-fg">.</span>summarize<span class="ansi-blue-fg">(</span>factTable<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/local_disk0/tmp/1644204967524-0/dbutils.py</span> in <span class="ansi-cyan-fg">__getattr__</span><span class="ansi-blue-fg">(self, item)</span>
# <span class="ansi-green-intense-fg ansi-bold">    563</span>             <span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>credentials
# <span class="ansi-green-intense-fg ansi-bold">    564</span>
# <span class="ansi-green-fg">--&gt; 565</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">raise</span> AttributeError
# <span class="ansi-green-intense-fg ansi-bold">    566</span>
# <span class="ansi-green-intense-fg ansi-bold">    567</span>     <span class="ansi-green-fg">def</span> __repr__<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">AttributeError</span>: </div>

# %%
# However, we can filter more:
myCountryCode = "GBR"
myIndicatorCode = "AG.LND.AGRI.ZS"
myYearCode = "1984"

filterTableYearValue = factTable.join(dimTableIndicator, factTable.indicatorCode == dimTableIndicator.indicatorCode, 'inner').filter(dimTableIndicator.indicatorCode == myIndicatorCode).join(dimTableDate, factTable.dateYear == dimTableDate.dateYear, 'inner').join(dimTableCountry, factTable.regionCode == dimTableCountry.regionCode, 'inner').filter(dimTableCountry.regionCode == myCountryCode)

filterTableIndicatorValue = factTable.join(dimTableIndicator, factTable.indicatorCode == dimTableIndicator.indicatorCode, 'inner').join(dimTableDate, factTable.dateYear == dimTableDate.dateYear, 'inner').filter(dimTableDate.dateYear == myYearCode).join(dimTableCountry, factTable.regionCode == dimTableCountry.regionCode, 'inner').filter(dimTableCountry.regionCode == myCountryCode)

filterTableCountryValue = factTable.join(dimTableIndicator, factTable.indicatorCode == dimTableIndicator.indicatorCode, 'inner').filter(dimTableIndicator.indicatorCode == myIndicatorCode).join(dimTableDate, factTable.dateYear == dimTableDate.dateYear, 'inner').filter(dimTableDate.dateYear == myYearCode).join(dimTableCountry, factTable.regionCode == dimTableCountry.regionCode, 'inner')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.data.summarize(filterTableYearValue.select(filterTableYearValue.dateYear, col("value")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2203931831861036&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>dbutils<span class="ansi-blue-fg">.</span>data<span class="ansi-blue-fg">.</span>summarize<span class="ansi-blue-fg">(</span>filterTableYearValue<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/local_disk0/tmp/1644204967524-0/dbutils.py</span> in <span class="ansi-cyan-fg">__getattr__</span><span class="ansi-blue-fg">(self, item)</span>
# <span class="ansi-green-intense-fg ansi-bold">    563</span>             <span class="ansi-green-fg">return</span> self<span class="ansi-blue-fg">.</span>credentials
# <span class="ansi-green-intense-fg ansi-bold">    564</span>
# <span class="ansi-green-fg">--&gt; 565</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">raise</span> AttributeError
# <span class="ansi-green-intense-fg ansi-bold">    566</span>
# <span class="ansi-green-intense-fg ansi-bold">    567</span>     <span class="ansi-green-fg">def</span> __repr__<span class="ansi-blue-fg">(</span>self<span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">AttributeError</span>: </div>

# %%
dbutils.data.summarize(filterTableIndicatorValue.select(filterTableIndicatorValue.indicatorName, col("value")))

# %%
dbutils.data.summarize(filterTableCountryValue.select(filterTableCountryValue.countryName, col("value")))

# %%
# Explore question (2) - For the UK table, can we calculate the rolling average over N years for each indicator?
from pyspark.sql.window import Window
from pyspark.sql.functions import avg, row_number

ukTable = spark.table("uktable").na.drop("any")
rollingAvgYear = 9

windowSpec = Window.partitionBy("indicatorName").orderBy(col("year").cast('long')).rangeBetween(-(rollingAvgYear), 0)
windowDf = ukTable.withColumn("avg", avg(col("value")).over(windowSpec)).select(col("indicatorName"), col("avg"), col("year"))
display(windowDf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>indicatorName</th><th>avg</th><th>year</th></tr></thead><tbody><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>1990</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>1991</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>1992</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>1993</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>1994</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>1995</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>1996</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>1997</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>1998</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>1999</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2000</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2001</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2002</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2003</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2004</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2005</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2006</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2007</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2008</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2009</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2010</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2011</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2012</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2013</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2014</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2015</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2016</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2017</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2018</td></tr><tr><td>Access to electricity (% of population)</td><td>100.0</td><td>2019</td></tr><tr><td>Agricultural land (% of land area)</td><td>81.84185508</td><td>1961</td></tr><tr><td>Agricultural land (% of land area)</td><td>81.79845409500001</td><td>1962</td></tr><tr><td>Agricultural land (% of land area)</td><td>81.73989721333334</td><td>1963</td></tr><tr><td>Agricultural land (% of land area)</td><td>81.665151075</td><td>1964</td></tr><tr><td>Agricultural land (% of land area)</td><td>81.522754514</td><td>1965</td></tr><tr><td>Agricultural land (% of land area)</td><td>81.40371181666667</td><td>1966</td></tr><tr><td>Agricultural land (% of land area)</td><td>81.32104327571429</td><td>1967</td></tr><tr><td>Agricultural land (% of land area)</td><td>81.1929070375</td><td>1968</td></tr><tr><td>Agricultural land (% of land area)</td><td>81.07211911444445</td><td>1969</td></tr><tr><td>Agricultural land (% of land area)</td><td>80.756003801</td><td>1970</td></tr><tr><td>Agricultural land (% of land area)</td><td>80.360434835</td><td>1971</td></tr><tr><td>Agricultural land (% of land area)</td><td>79.937585251</td><td>1972</td></tr><tr><td>Agricultural land (% of land area)</td><td>79.50316207099999</td><td>1973</td></tr><tr><td>Agricultural land (% of land area)</td><td>79.062952093</td><td>1974</td></tr><tr><td>Agricultural land (% of land area)</td><td>78.648782705< ...

# %%
# Explore question (3) - For the 2012 table, can we calculate which countries have the min/max value for each indicator?
from pyspark.sql.functions import min, max
table2012 = spark.table("2012table").na.drop("any")
aggTable = table2012.groupBy("indicatorName").agg(min("value").alias("minValue"), max("value").alias("maxValue")).withColumnRenamed("indicatorName", "indicator")
minTable = table2012.join(aggTable, table2012.indicatorName == aggTable.indicator).filter(table2012.value == aggTable.minValue).select(table2012.countryName, aggTable.indicator, table2012.value)
maxTable = table2012.join(aggTable, table2012.indicatorName == aggTable.indicator).filter(table2012.value == aggTable.maxValue).select(table2012.countryName, aggTable.indicator, table2012.value)
display(maxTable)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>countryName</th><th>indicator</th><th>value</th></tr></thead><tbody><tr><td>Suriname</td><td>Forest area (% of land area)</td><td>97.95246154</td></tr><tr><td>Libya</td><td>GDP growth (annual %)</td><td>123.1395552</td></tr><tr><td>World</td><td>GDP (current US$)</td><td>7.5356E13</td></tr><tr><td>Kiribati</td><td>Government expenditure on education, total (% of GDP)</td><td>13.38438034</td></tr><tr><td>Brazil</td><td>Income share held by highest 20%</td><td>58.2</td></tr><tr><td>Ukraine</td><td>Income share held by lowest 20%</td><td>10.2</td></tr><tr><td>Equatorial Guinea</td><td>Industry (including construction), value added (% of GDP)</td><td>77.31150427</td></tr><tr><td>Belarus</td><td>Inflation, consumer prices (annual %)</td><td>59.21973602</td></tr><tr><td>San Marino</td><td>Life expectancy at birth, total (years)</td><td>85.41707317</td></tr><tr><td>Aruba</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Andorra</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>United Arab Emirates</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Antigua and Barbuda</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Australia</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Austria</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Azerbaijan</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Belgium</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Bulgaria</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Bahrain</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Bahamas, The</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Bosnia and Herzegovina</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Belarus</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Bermuda</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Barbados</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Brunei Darussalam</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Canada</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Central Europe and the Baltics</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Switzerland</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Channel Islands</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Chile</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Curacao</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Cayman Islands</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Cyprus</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Czech Republic</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Germany</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Denmark</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Euro area</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Spain</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Estonia</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>European Union</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Finland</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>France</td><td>Access to electricity (% of population)</td><td>100.0</td></tr><tr><td>Faroe Islands</td><td>Access ...

# %%
# Explore question (4) - For the Education table, can we calculate which country has the worst gender split for literacy rates in a given year?
from pyspark.sql.functions import min, max
educationTable = spark.table("educationTable")
educationTable = educationTable.join(dimTableIndicator, educationTable.indicatorName == dimTableIndicator.indicatorName).filter(dimTableIndicator.indicatorCode.like('SE.ADT.LITR.%.ZS')).select(col("countryName"), dimTableIndicator.indicatorName, col("year"), col("value")).na.drop("any")
genderSplitTable = educationTable.groupBy(['countryName', 'year']).agg(min("value").alias("minValue"), max("value").alias("maxValue"))
genderSplitTable = genderSplitTable.withColumn('genderSplit', (genderSplitTable['maxValue'] - genderSplitTable['minValue'])).select(col("countryName"), col("year"), col("genderSplit"))
genderSplitMinMax = genderSplitTable.groupBy("year").agg(min("genderSplit").alias("minGenderSplit"), max("genderSplit").alias("maxGenderSplit"))
genderSplitMinTable = genderSplitMinMax.join(genderSplitTable, genderSplitMinMax.year == genderSplitTable.year).filter(genderSplitTable.genderSplit == genderSplitMinMax.minGenderSplit).select(col("countryName"), genderSplitMinMax.year, genderSplitMinMax.minGenderSplit)
genderSplitMaxTable = genderSplitMinMax.join(genderSplitTable, genderSplitMinMax.year == genderSplitTable.year).filter(genderSplitTable.genderSplit == genderSplitMinMax.maxGenderSplit).select(col("countryName"), genderSplitMinMax.year, genderSplitMinMax.maxGenderSplit)
display(genderSplitMaxTable)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>countryName</th><th>year</th><th>maxGenderSplit</th></tr></thead><tbody><tr><td>Middle East & North Africa (IDA & IBRD countries)</td><td>1982</td><td>28.05798912</td></tr><tr><td>South Asia (IDA & IBRD)</td><td>1996</td><td>25.4752388</td></tr><tr><td>South Asia</td><td>1993</td><td>26.42724991</td></tr><tr><td>South Asia (IDA & IBRD)</td><td>1989</td><td>26.822820669999995</td></tr><tr><td>South Asia</td><td>1999</td><td>25.23653412</td></tr><tr><td>Middle East & North Africa (IDA & IBRD countries)</td><td>